# %%
# In first  Importing  some library and using  the filter warning for ignoring the warning sign
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# I Importing the data file 
df =pd.read_csv('/content/data.csv')

# %%
# After importing the data File i used the df.head to know about the top 5 row of data and its type 
df.head()
# Out:
#    origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0       1          8         307.0        130    3504          12.0  1970
# 1       1          8         350.0        165    3693          11.5  1970
# 2       1          8         318.0        150    3436          11.0  1970
# 3       1          8         304.0        150    3433          12.0  1970
# 4       1          8         302.0        140    3449          10.5  1970
#
#                         name  Kilometer_per_liter
# 0  chevrolet chevelle malibu             7.652587
# 1          buick skylark 320             6.377156
# 2         plymouth satellite             7.652587
# 3              amc rebel sst             6.802299
# 4                ford torino             7.227443

# %%
# This one i use to know about the bottom of the row 
df.tail()
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 393       1          4         140.0         86    2790          15.6  1982
# 394       2          4          97.0         52    2130          24.6  1982
# 395       1          4         135.0         84    2295          11.6  1982
# 396       1          4         120.0         79    2625          18.6  1982
# 397       1          4         119.0         82    2720          19.4  1982
#
#                 name  Kilometer_per_liter
# 393  ford mustang gl            11.478880
# 394        vw pickup            18.706323
# 395    dodge rampage            13.604599
# 396      ford ranger            11.904024
# 397       chevy s-10            13.179455

# %%
# it tell about the whole information about the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# It tell about the types of data 
df.dtypes
# Out:
# origin                   int64
# cylinders                int64
# displacement           float64
# horsepower              object
# weight                   int64
# acceleration           float64
# year                     int64
# name                    object
# Kilometer_per_liter    float64
# dtype: object

# %%
# I use this to expand the Insight the  rows of  all the columns of the data  
pd.set_option('max_rows', None)

# %%
# I use this get to know how many strings are present In each row  
df['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
# 5      198
# 6      220
# 7      215
# 8      225
# 9      190
# 10     170
# 11     160
# 12     150
# 13     225
# 14      95
# 15      95
# 16      97
# 17      85
# 18      88
# 19      46
# 20      87
# 21      90
# 22      95
# 23     113
# 24      90
# 25     215
# 26     200
# 27     210
# 28     193
# 29      88
# 30      90
# 31      95
# 32       ?
# 33     100
# 34     105
# 35     100
# 36      88
# 37     100
# 38     165
# 39     175
# 40     153
# 41     150
# 42     180
# 43     170
# 44     175
# 45     110
# 46      72
# 47     100
# 48      88
# 49      86
# 50      90
# 51      70
# 52      76
# 53      65
# 54      69
# 55      60
# 56      70
# 57      95
# 58      80
# 59      54
# 60      90
# 61      86
# 62     165
# 63     175
# 64     150
# 65     153
# 66     150
# 67     208
# 68     155
# 69     160
# 70     190
# 71      97
# 72     150
# 73     130
# 74     140
# 75     150
# ...

# %%
#Data Preprocessing
#Handling of missing values
#Replacing of values using replace function
df['horsepower'] = df['horsepower'].replace('?',np.nan)

# %%
#Changing of data type
df['horsepower'] = df['horsepower'].astype('float')

# %%
# Filling the Nan Value by Median 
df['horsepower'].fillna(df['horsepower'].median(),inplace=True)

# %%
# label Encoder
from sklearn.preprocessing import LabelEncoder

# %%
#Object assigned
le = LabelEncoder()

# %%
# name encoding (it convert the name from object to int and and filled the values of all row) when more number of 
# objects are present in one colums of the data we use label encoder 
df['name'] = le.fit_transform(df['name'])

# %%
# To check the data again after Data Processing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    float64
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    int64
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.1 KB

# %%
 #Correlation - Ranges from -1 to +1
 a = df.corr()
 a
# Out:
#                        origin  cylinders  displacement  horsepower    weight  \
# origin               1.000000  -0.562543     -0.609409   -0.452096 -0.581024
# cylinders           -0.562543   1.000000      0.950721    0.841284  0.896017
# displacement        -0.609409   0.950721      1.000000    0.895778  0.932824
# horsepower          -0.452096   0.841284      0.895778    1.000000  0.862442
# weight              -0.581024   0.896017      0.932824    0.862442  1.000000
# acceleration         0.205873  -0.505419     -0.543684   -0.686590 -0.417457
# year                 0.180662  -0.348746     -0.370164   -0.413733 -0.306564
# name                 0.360058  -0.275754     -0.292064   -0.233575 -0.255247
# Kilometer_per_liter  0.563450  -0.775396     -0.804203   -0.773453 -0.831741
#
#                      acceleration      year      name  Kilometer_per_liter
# origin                   0.205873  0.180662  0.360058             0.563450
# ...

# %%
#  To check the correlation value of one columns  
x = a[['Kilometer_per_liter']]
x
# Out:
#                      Kilometer_per_liter
# origin                          0.563450
# cylinders                      -0.775396
# displacement                   -0.804203
# horsepower                     -0.773453
# weight                         -0.831741
# acceleration                    0.420289
# year                            0.579267
# name                            0.273936
# Kilometer_per_liter             1.000000

# %%
# drop the  columns of negative correlation values 
df.drop(['cylinders','displacement','horsepower','weight'],axis=1,inplace=True)

# %%
# To check the top 5 rows 
df.head()
# Out:
#    origin  acceleration  year  name  Kilometer_per_liter
# 0       1          12.0  1970    49             7.652587
# 1       1          11.5  1970    36             6.377156
# 2       1          11.0  1970   231             7.652587
# 3       1          12.0  1970    14             6.802299
# 4       1          10.5  1970   161             7.227443

# %%
# check the correltion after droping the neagtive corr values of columns and in insight  no negative values are left  
b = df.corr()
b
# Out:
#                        origin  acceleration      year      name  \
# origin               1.000000      0.205873  0.180662  0.360058
# acceleration         0.205873      1.000000  0.288137  0.128285
# year                 0.180662      0.288137  1.000000  0.074761
# name                 0.360058      0.128285  0.074761  1.000000
# Kilometer_per_liter  0.563450      0.420289  0.579267  0.273936
#
#                      Kilometer_per_liter
# origin                          0.563450
# acceleration                    0.420289
# year                            0.579267
# name                            0.273936
# Kilometer_per_liter             1.000000

# %%
#  To check  the positive correlation values 
a1 = b[['Kilometer_per_liter']]
a1
# Out:
#                      Kilometer_per_liter
# origin                          0.563450
# acceleration                    0.420289
# year                            0.579267
# name                            0.273936
# Kilometer_per_liter             1.000000

# %%
#importing matlpotlib & seaborn libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Correlation Plotting/Visualization
plt.figure(figsize=(25,15))
sns.heatmap(a1,vmax=1.0,vmin=-1.0,fmt='g',cmap='RdYlGn',annot=True)
plt.title('Kilometer_per_liter',fontsize=20)
plt.show()

# %%
# check the numbers of columns
df.columns
# Out:
# Index(['origin', 'acceleration', 'year', 'name', 'Kilometer_per_liter'], dtype='object')

# %%
# X is Independent variable storing indpenedent columns into x 
X = df[['origin','acceleration', 'year', 'name']]

# %%
# check the top 5 row 
X.head()
# Out:
#    origin  acceleration  year  name
# 0       1          12.0  1970    49
# 1       1          11.5  1970    36
# 2       1          11.0  1970   231
# 3       1          12.0  1970    14
# 4       1          10.5  1970   161

# %%
# y is Dependent variable its our prdicted data 
y = df[['Kilometer_per_liter']]

# %%
# Top 5 rows
y.head()
# Out:
#    Kilometer_per_liter
# 0             7.652587
# 1             6.377156
# 2             7.652587
# 3             6.802299
# 4             7.227443

# %%
# it convert the values into array store into small x 
x = X.values.reshape(-1,1)

# %%
x
# Out:
# array([[1.000e+00],
#        [1.200e+01],
#        [1.970e+03],
#        ...,
#        [1.940e+01],
#        [1.982e+03],
#        [6.900e+01]])

# %%
# it convert the values into array store into small y
y = y.values.reshape(-1,1)

# %%
y
# Out:
# array([[ 7.65258673],
#        [ 6.37715561],
#        [ 7.65258673],
#        [ 6.80229932],
#        [ 7.22744303],
#        [ 6.37715561],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
#        [ 6.37715561],
#        [ 6.37715561],
#        [ 5.9520119 ],
#        [ 6.37715561],
#        [ 5.9520119 ],
#        [10.20344898],
#        [ 9.35316156],
#        [ 7.65258673],
#        [ 8.92801786],
#        [11.4788801 ],
#        [11.05373639],
#        [10.62859269],
#        [10.20344898],
#        [10.62859269],
#        [11.05373639],
#        [ 8.92801786],
#        [ 4.25143707],
#        [ 4.25143707],
#        [ 4.67658078],
#        [ 3.82629337],
#        [11.4788801 ],
#        [11.90402381],
#        [10.62859269],
#        [10.62859269],
#        [ 8.07773044],
#        [ 6.80229932],
#        [ 7.22744303],
#        [ 8.07773044],
#        [ 7.65258673],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
# ...

# %%
# importing the main library + sub library and function library for spilitting the data 
from sklearn.model_selection import train_test_split

# %%
#spilitting of Data
# the best range to spilitting the data is 70% to 30%  
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,train_size=0.7,random_state=1)

# %%
# Number of Rows and columns in train model of X
X_train.shape
# Out:
# (278, 4)

# %%
# Number of Rows and Columns in test model of X
X_test.shape
# Out:
# (120, 4)

# %%
# total Number of Rows and Columns in X 
X.shape
# Out:
# (398, 4)

# %%
# Number of Rows and columns in train model of y
y_train.shape
# Out:
# (278, 1)

# %%
# Number of Rows and Columns in test model of y
y_test.shape
# Out:
# (120, 1)

# %%
# total Number of Rows and Columns in y
y.shape
# Out:
# (398, 1)

# %%
#importing linear Regression
from sklearn.linear_model import LinearRegression

# %%
#object Creation
model = LinearRegression()

# %%
# Training the model using the .fit() Function
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
 #testing the data/model or predicting the data or predicting the model
y_hat = model.predict(X_test)

# %%
y_hat
# Out:
# array([[ 8.48802402],
#        [14.26146109],
#        [ 9.27224073],
#        [11.28690138],
#        [10.63340893],
#        [ 9.32826352],
#        [10.45069125],
#        [15.28241188],
#        [ 8.30810366],
#        [ 7.30460495],
#        [11.58728297],
#        [10.60128105],
#        [ 9.42375232],
#        [10.09537558],
#        [15.17751435],
#        [10.52514674],
#        [ 5.22621437],
#        [ 8.77672175],
#        [ 7.00761043],
#        [14.33683091],
#        [12.14740604],
#        [11.32912463],
#        [ 6.78154644],
#        [ 9.87553078],
#        [11.52232937],
#        [11.34038776],
#        [15.11880561],
#        [14.2788945 ],
#        [ 5.41399504],
#        [11.12970398],
#        [11.47763264],
#        [ 4.70862839],
#        [10.30253358],
#        [13.22949397],
#        [ 9.98528136],
#        [ 6.88198185],
#        [ 9.55695052],
#        [ 6.38469043],
#        [10.53615142],
#        [ 8.42964367],
#        [ 7.72840701],
# ...

# %%
# importing of r2 Library
from sklearn.metrics import r2_score

# %%
# Applying r2 formula to find out the r2 and its range between 0 to + 1 
r2_score(y_test,y_hat)*100
# Out:
# 64.78613621156352

# %%
# Adjusted R_square  
# here [1] tell the row 
adj_r2_score = 1-(1-model.score(X_test,y_test))*len((y_train)-1)/(len(y_train)-y_test.shape[1]-1)

# %%
# Adjusted r2 always in range between -1 to +1 and its closer to r2 but never greater then r2
adj_r2_score*100
# Out:
# 64.53096328556036

# %%
# importing the library of mean_square_error 
from sklearn.metrics import mean_squared_error

# %%
# its range always between -infinite to + infinite we are applying formula to find out mean_square_error
mean_squared_error(y_test,y_hat)
# Out:
# 3.7213075829985995

# %%
# multi colinearity
1/1-model.score(X_test,y_test)
# Out:
# 0.35213863788436484
