# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Read file

# %%
df=pd.read_csv(r'C:\Users\hp\OneDrive\Documents\insurance.csv')

# %% [markdown]
# # SHOWS THE TOP 5 DATA

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # IT SHOWS THE INFORMATION OF DATA AND ITS TYPE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# IT DESCRIBE THE COLUMN AS TOTAL COUNTS AND ALL

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# IT SHOWS TOTAL COUNTS OF EACH DATA

# %%
df[['age']].value_counts()
# Out:
# age
# 18     69
# 19     68
# 20     29
# 51     29
# 45     29
# 46     29
# 47     29
# 48     29
# 50     29
# 52     29
# 28     28
# 54     28
# 21     28
# 27     28
# 26     28
# 49     28
# 25     28
# 24     28
# 23     28
# 22     28
# 53     28
# 42     27
# 44     27
# 43     27
# 41     27
# 40     27
# 31     27
# 30     27
# 29     27
# 56     26
# 34     26
# 33     26
# 32     26
# 57     26
# 55     26
# 35     25
# 59     25
# 58     25
# 36     25
# 39     25
# 38     25
# 37     25
# 60     23
# 61     23
# 62     23
# 63     23
# 64     22
# dtype: int64

# %%
df[['bmi']].value_counts()
# Out:
# bmi
# 32.300    13
# 28.310     9
# 30.875     8
# 31.350     8
# 28.880     8
#           ..
# 28.800     1
# 28.490     1
# 28.380     1
# 28.200     1
# 53.130     1
# Length: 548, dtype: int64

# %%
df[['children']].value_counts()
# Out:
# children
# 0           574
# 1           324
# 2           240
# 3           157
# 4            25
# 5            18
# dtype: int64

# %%
df[['charges']].value_counts()
# Out:
# charges
# 1639.56310     2
# 12741.16745    1
# 12949.15540    1
# 12928.79110    1
# 12925.88600    1
#               ..
# 6272.47720     1
# 6250.43500     1
# 6238.29800     1
# 6203.90175     1
# 63770.42801    1
# Length: 1337, dtype: int64

# %% [markdown]
# IT DISPLAYS THE TOTAL NO. OF  NULL VALUES AS TRUE

# %%
df.isna().apply(pd.value_counts).T
# Out:
#           False
# age        1338
# sex        1338
# bmi        1338
# children   1338
# smoker     1338
# region     1338
# charges    1338

# %% [markdown]
# ITS A LABEL ENCODER TO FILL THE VALUES IN PLACE OF OBJECT

# %%
df['sex']=le.fit_transform(df['sex'])

# %%
df['smoker'] = le.fit_transform(df['smoker'])

# %%
df['region'] = le.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# # CORELATION

# %%
corr=df.corr()
corr
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000 -0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208  1.000000

# %% [markdown]
# SHOW CORELATION MATRIX AS IN A MATRIX FORM AND HEATMAP IS LIKE FILL THE COLOUR OR PRESENT IN A GRAPHICAL WAY

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr,vmax=1.0,vmin=-1.0,fmt='g',cmap='RdYlGn',annot=True)
plt.title('Correlation_Matrix',fontsize=20)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int32
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int32
#  5   region    1338 non-null   int32
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int32(3), int64(2)
# memory usage: 57.6 KB

# %% [markdown]
# WE HAVE TAKEN 'CHARGES' CORRELATION VALUES IN A USING CORR FUNCTION

# %%
a=corr[['charges']]
a
# Out:
#            charges
# age       0.299008
# sex       0.057292
# bmi       0.198341
# children  0.067998
# smoker    0.787251
# region   -0.006208
# charges   1.000000

# %% [markdown]
# ITS A CODE FOR MAKING DISPLOT

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['charges'])
plt.title('Distplot',fontsize=20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['sex'])
plt.title('Distplot',fontsize=20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.038101
# charges     1.515880
# dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['bmi'])
plt.title('Distplot',fontsize=20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['age'])
plt.title('Distplot',fontsize=20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['children'])
plt.title('Distplot',fontsize=20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['region'])
plt.title('Distplot',fontsize=20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['smoker'])
plt.title('Distplot',fontsize=20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df.children)
plt.title('boxplot',fontsize=15)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'boxplot')

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# sex       1338.0      0.505232      0.500160     0.0000     0.00000     1.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# smoker    1338.0      0.204783      0.403694     0.0000     0.00000     0.000
# region    1338.0      1.515695      1.104885     0.0000     1.00000     2.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# sex           1.000000      1.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# smoker        0.000000      1.00000
# region        2.000000      3.00000
# charges   16639.912515  63770.42801

# %%
pd.set_option('display.max_rows',None)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
x=df[['age','sex','bmi','children','smoker','region']]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# 5      31    0  25.740         0       0       2
# 6      46    0  33.440         1       0       2
# 7      37    0  27.740         3       0       1
# 8      37    1  29.830         2       0       0
# 9      60    0  25.840         0       0       1
# 10     25    1  26.220         0       0       0
# 11     62    0  26.290         0       1       2
# 12     23    1  34.400         0       0       3
# 13     56    0  39.820         0       0       2
# 14     27    1  42.130         0       1       2
# 15     19    1  24.600         1       0       3
# 16     52    0  30.780         1       0       0
# 17     23    1  23.845         0       0       0
# ...

# %%
y=df[['charges']]
y
# Out:
#            charges
# 0     16884.924000
# 1      1725.552300
# 2      4449.462000
# 3     21984.470610
# 4      3866.855200
# 5      3756.621600
# 6      8240.589600
# 7      7281.505600
# 8      6406.410700
# 9     28923.136920
# 10     2721.320800
# 11    27808.725100
# 12     1826.843000
# 13    11090.717800
# 14    39611.757700
# 15     1837.237000
# 16    10797.336200
# 17     2395.171550
# 18    10602.385000
# 19    36837.467000
# 20    13228.846950
# 21     4149.736000
# 22     1137.011000
# 23    37701.876800
# 24     6203.901750
# 25    14001.133800
# 26    14451.835150
# 27    12268.632250
# 28     2775.192150
# 29    38711.000000
# 30    35585.576000
# 31     2198.189850
# 32     4687.797000
# 33    13770.097900
# 34    51194.559140
# 35     1625.433750
# 36    15612.193350
# 37     2302.300000
# 38    39774.276300
# 39    48173.361000
# 40     3046.062000
# 41     4949.758700
# 42     6272.477200
# 43     6313.759000
# 44     6079.671500
# 45    20630.283510
# ...

# %%
#independent variable
from sklearn.model_selection import train_test_split

# %%
#take variables
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,test_size=0.3,random_state=1)

# %%
x_train.shape
# Out:
# (936, 6)

# %%
x_test.shape
# Out:
# (402, 6)

# %%
y_train.shape
# Out:
# (936, 1)

# %%
y_test.shape
# Out:
# (402, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
#training the model using the .fit()function
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[ 4.50048433e+03],
#        [ 1.28194579e+04],
#        [ 1.23977127e+04],
#        [ 1.34303433e+04],
#        [ 5.31776110e+02],
#        [ 3.22642696e+04],
#        [ 1.30762461e+04],
#        [ 1.22348298e+04],
#        [ 3.82932402e+03],
#        [ 3.01565286e+04],
#        [ 1.13198257e+04],
#        [ 1.72084618e+04],
#        [ 8.91832075e+03],
#        [ 8.22883518e+03],
#        [ 3.58166904e+03],
#        [ 1.01918742e+04],
#        [ 3.97134424e+03],
#        [ 6.75521017e+03],
#        [ 1.52141457e+04],
#        [ 1.42498228e+04],
#        [ 1.24184207e+04],
#        [ 3.34497470e+04],
#        [ 9.12417099e+03],
#        [ 8.85380484e+03],
#        [ 3.13406481e+03],
#        [ 8.14417612e+03],
#        [ 9.33914668e+03],
#        [ 1.10793027e+04],
#        [ 7.54531559e+03],
#        [ 4.40537383e+03],
#        [ 1.39112972e+04],
#        [ 5.64886526e+03],
#        [ 3.46827850e+04],
#        [ 2.74022377e+04],
#        [ 3.38105315e+04],
# ...

# %%
from sklearn.metrics import r2_score

# %%
# R-Square
r2_score(y_test,y_pred)*100
# Out:
# 74.0367716897532

# %%
#alternate method of R-Square
model.score(x_test,y_test)*100
# Out:
# 74.0367716897532

# %%
model.score(x_train,y_train)
# Out:
# 0.7544083642384214

# %%
adj_r2_score=1-(1-model.score(x_test,y_test))*len((y_train)-1)/(len(y_train)-y_test.shape[1]-1)
adj_r2_score
# Out:
# 0.7398117591178692

# %%
adj_r2_score*100
# Out:
# 73.98117591178692

# %%
from sklearn.metrics import mean_squared_error

# %%
sns.regplot(x=x_test['age'],y=y_test,truncate=False)
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>
