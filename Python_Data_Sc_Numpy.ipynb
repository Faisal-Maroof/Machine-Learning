# %%
import numpy as np

# %%
a = [5,2,7,4,1]

# %%
a
# Out:
# [5, 2, 7, 4, 1]

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 5

# %%
#Converting a list into an array
b = np.array(a)

# %%
b
# Out:
# array([5, 2, 7, 4, 1])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
a = np.array([[5,2,7],[4,1,8],[11,17,25]])

# %%
a
# Out:
# array([[ 5,  2,  7],
#        [ 4,  1,  8],
#        [11, 17, 25]])

# %%
a.shape
# Out:
# (3, 3)

# %%
a.mean()
# Out:
# 8.88888888888889

# %%
b = np.random.randn(5,5)
b
# Out:
# array([[-1.79961995,  0.45802948, -0.19656782, -1.95689968,  0.41916431],
#        [ 0.57549716,  0.6139438 ,  0.18345451,  0.65730429,  0.48497279],
#        [ 0.60519808,  1.42486582, -0.99943178, -0.30026154,  1.10333606],
#        [-0.60260818, -0.07113552, -0.3818648 , -0.70580458, -1.6122502 ],
#        [ 0.25448193, -0.22246388, -0.99188238, -1.4742657 ,  0.04429054]])

# %%
b.shape
# Out:
# (5, 5)

# %%
import pandas as pd

# %%
c = pd.DataFrame(b)

# %%
c
# Out:
#           0         1         2         3         4
# 0 -1.799620  0.458029 -0.196568 -1.956900  0.419164
# 1  0.575497  0.613944  0.183455  0.657304  0.484973
# 2  0.605198  1.424866 -0.999432 -0.300262  1.103336
# 3 -0.602608 -0.071136 -0.381865 -0.705805 -1.612250
# 4  0.254482 -0.222464 -0.991882 -1.474266  0.044291

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df1 = pd.read_csv(r'C:\Users\hp\Desktop\iris.csv')

# %%
df1.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
pd.set_option('display.max_rows',150)

# %%
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           1.4          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          0.2      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 6             4.6          3.4           1.4          0.3      Setosa
# 7             5.0          3.4           1.5          0.2      Setosa
# 8             4.4          2.9           1.4          0.2      Setosa
# 9             4.9          3.1           1.5          0.1      Setosa
# 10            5.4          3.7           1.5          0.2      Setosa
# 11            4.8          3.4           1.6          0.2      Setosa
# ...
